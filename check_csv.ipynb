# %%
#import the module what we used
import pandas as pd
import os
import os.path
if not os.path.isdir("dataset_full"):
    os.mkdir("dataset_full")
brand_list = ['SAMSUNG', 'Apple', 'OPPO', 'ASUS', 'HUAWEI', 'Sony', '小米', 'HTC', 'Nokia', 'realme', \
              'Google', 'LG', 'SUGAR', 'SHARP', 'koobee', 'vivo']

index = 1   #只要改index的數字就可以了
df = pd.read_csv("./dataset_full/" + brand_list[index] + ".csv",sep = ",")
df

# df = pd.read_csv("./total.csv",sep = ",")
# df
# Out:
#                              手機型號   空機價格     二手價格     上市日期  經過的月份數  \
# 0     Apple iPhone SE (2020) 64GB  12900  11998.0  2020/04       2
# 1           Apple iPhone 11 128GB  23500  20676.0  2019/09       9
# 2       Apple iPhone 7 Plus 128GB  13890   8250.0  2016/09      45
# 3        Apple iPhone 8 Plus 64GB  16890  10037.0  2017/09      33
# 4            Apple iPhone 11 64GB  21600  19399.0  2019/09       9
# 5            Apple iPhone XR 64GB  18800  13581.0  2018/10      20
# 6    Apple iPhone SE (2020) 128GB  14600  13833.0  2020/04       2
# 7   Apple iPhone 11 Pro Max 256GB  38800  36100.0  2019/09       9
# 8             Apple iPhone 8 64GB  14290   7844.0  2017/09      33
# 9            Apple iPhone XS 64GB  21500  16446.0  2018/09      21
# 10       Apple iPhone XS Max 64GB  25800  19250.0  2018/09      21
# 11           Apple iPhone 7 128GB  11500   6061.0  2016/09      45
# 12          Apple iPhone XR 128GB  19500  14860.0  2018/10      20
# ...
