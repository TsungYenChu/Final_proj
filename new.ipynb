# %%
#import the module what we used
import requests
from pyquery import PyQuery as pq
import pandas as pd

# add the website with the url into the pyquery
url = "https://www.sogi.com.tw/"
html = requests.get(url+"brands/").text
txt = pq(html)

# Find all of the brands in this site
links =txt("#main > div:nth-child(2) > div:nth-child(1) > div:nth-child(n+1) a")
brands = txt("#main > div:nth-child(2) > div:nth-child(1)").find(".text-center p")
link_list, brand_list = [],[]
for link in links: 
    link_list.append(pq(link).attr('href'))
for brand in range(len(brands)):
    tmp = str(brands.eq(brand).text()).split("(")
    brand_list.append(tmp[0].replace(" ",""))
# [(link_list[i]) for i in range(len(link_list))]
# [(brand_list[i]) for i in range(len(brand_list))]
link_list.pop(-2)
brand_list.pop(-2)
# To pick up the information about cellphone, because this site have the info of tablet and wearable
for index in range(len(link_list)):
    print("[{:>2d}/{}] {} start.".format(index+1,len(link_list),brand_list[index]))
    brand = pq(requests.get(url+link_list[index]).text)
    text =brand.find(".fcellphone").not_('div.mix-item.col-12.col-lg-4.cat1.cat2.cat3.fcellphone.ftablet.fwearable')
    # print(str(brand('#section-list')('#mixitup-1').find(".fcellphone").text()))
    # brand.find(".col-12").find(".d-inline-block").text()
    # brand.find(".fcellphone").not_(".iframe-rwd").text()
    name, price, price_first, price_second, date = [],[],[],[],[]
    # Find the name of phones
    pqname = text.find(".text-row-1")+text.find(".text-row-2")
    for i in range(len(pqname)):
        name.append(pqname.eq(i).text())
    # Find the price of phones
    pqprice = text.find(".d-block").not_('.d-block text-center').not_('img').not_('a.d-block.text-center')
    for i in [0,1]:
        price.append(text.find(".d-inline-block").eq(3*i).text()+"\n"+text.find(".d-inline-block").eq(3*i+1).text()+"\n"+text.find(".d-inline-block").eq(3*i+2).text())
    for i in range(len(pqprice)):
        price.append(pqprice.eq(i).text())
    for i in range(len(price)):
        tmp = price[i].split("\n")
        if len(tmp)==3:
            a, b = tmp[0].split("$"), tmp[1].split("$")
            c = tmp[2].split("：")
            if a[-1] == "------":
                a[-1] = "Nan"
            else:
                a[-1] = int(a[-1].replace(",",""))
            if b[-1] == "------":
                b[-1] = "Nan"
            else:
                b[-1] = int(b[-1].replace(",",""))
            price_first.append(a[-1])
            price_second.append(b[-1])
            date.append(c[-1])
        else:
            a, b = tmp[0].split("$"),tmp[1].split("：")
            if a[-1] =="------":
                a[-1]= "Nan"
            else:
                a[-1] = int(a[-1].replace(",",""))
            price_first.append(a[-1])
            price_second.append("Nan")
            date.append(c[-1])
    # Combine the name and the price of the phone
    dic = {"Name":name, "Price":price_first, "Second-hand":price_second, "Listing date":date}
    df = pd.DataFrame(dic)
    #set up the path
    path = "C:/Users/tsung/OneDrive/桌面/Final_proj/" + brand_list[index] + ".csv"
    # save the data as csv
    df.to_csv(path, index = False, header=True)
    print("[{:>2d}/{}] {} complete.".format(index+1,len(link_list),brand_list[index]))
# Out:
# [ 1/16] SAMSUNG start.
# [ 1/16] SAMSUNG complete.
# [ 2/16] Apple start.
# [ 2/16] Apple complete.
# [ 3/16] OPPO start.
# [ 3/16] OPPO complete.
# [ 4/16] ASUS start.
# [ 4/16] ASUS complete.
# [ 5/16] HUAWEI start.
# [ 5/16] HUAWEI complete.
# [ 6/16] Sony start.
# [ 6/16] Sony complete.
# [ 7/16] 小米 start.
# [ 7/16] 小米 complete.
# [ 8/16] HTC start.
# [ 8/16] HTC complete.
# [ 9/16] Nokia start.
# [ 9/16] Nokia complete.
# [10/16] realme start.
# [10/16] realme complete.
# [11/16] Google start.
# [11/16] Google complete.
# [12/16] LG start.
# [12/16] LG complete.
# [13/16] SUGAR start.
# [13/16] SUGAR complete.
# [14/16] SHARP start.
# [14/16] SHARP complete.
# [15/16] koobee start.
# [15/16] koobee complete.
# [16/16] vivo start.
# [16/16] vivo complete.

# %%
df = pd.read_csv(r"C:\Users\tsung\OneDrive\桌面\Final_proj\SAMSUNG.csv",sep = ",")

# %%
df
# Out:
#                                  Name  Price Second-hand Listing date
# 0                  SAMSUNG Galaxy A71  11190         Nan      2020/02
# 1                  SAMSUNG Galaxy A51   8390        7333      2020/01
# 2                  SAMSUNG Galaxy A31   7600         Nan      2020/05
# 3                  SAMSUNG Galaxy M11   3990         Nan      2020/05
# 4                  SAMSUNG Galaxy A70   8200        7140      2019/05
# 5                  SAMSUNG Galaxy A20   3750        2850      2019/04
# 6         SAMSUNG Galaxy Note 10 Lite  15000       14600      2020/02
# 7               SAMSUNG Galaxy S20 5G  23700       23500      2020/03
# 8       SAMSUNG Galaxy Note 10+ 256GB  25200       22209      2019/08
# 9                 SAMSUNG Galaxy A30s   5800        4967      2019/10
# 10             SAMSUNG Galaxy Note 10  22800       19567      2019/08
# 11                 SAMSUNG Galaxy A60   6750        6260      2019/06
# 12                 SAMSUNG Galaxy S10  18400       13473      2019/03
# 13  SAMSUNG Galaxy S20 Ultra 5G 256GB  32700       31833      2020/03
# 14                SAMSUNG Galaxy S10+  20500       16163      2019/03
# 15             SAMSUNG Galaxy S20+ 5G  28200       25000      2020/03
# 16        SAMSUNG Galaxy Note 9 128GB  18500       13355      2018/08
# 17           SAMSUNG Galaxy A7 (2018)   6500        4200      2018/10
# 18                 SAMSUNG Galaxy A80  12990       11000      2019/06
# 19           SAMSUNG Galaxy A9 (2018)   7500        6858      2018/12
# 20              SAMSUNG Galaxy Z Flip  43400       34250      2020/02
# 21                SAMSUNG Galaxy Fold  67000         Nan      2020/01
# 22  SAMSUNG Galaxy S20 Ultra 5G 512GB  41900         Nan      2020/03
# 23      SAMSUNG Galaxy Note 10+ 512GB  32000         Nan      2019/08
# 24      SAMSUNG Galaxy S10+ 陶瓷版 512GB  27900         Nan      2019/03
# 25        SAMSUNG Galaxy S10+ 陶瓷版 1TB  30990         Nan      2019/03
# 26        SAMSUNG Galaxy Note 9 512GB  24500       17000      2018/08
# 27      SAMSUNG Galaxy Note 9 黑色沙漠限量版  31400         Nan      2018/08
# 28                SAMSUNG Galaxy A21s   6990         Nan      2018/08
# 29              SAMSUNG Galaxy Note 8  29900        9138      2017/09
# 30                 SAMSUNG Galaxy A30   8990         Nan      2019/03
# 31                SAMSUNG Galaxy S10e  15900       15000      2019/03
# 32                  SAMSUNG GALAXY J7   7990         Nan      2015/08
# 33                  SAMSUNG Galaxy S8  24900       16990      2017/05
# 34         SAMSUNG GALAXY Note 5 32GB  23880        5833      2015/08
# 35  SAMSUNG Galaxy A90 5G (6GB/128GB)    Nan         Nan      2015/08
# 36                 SAMSUNG Galaxy A10    Nan         Nan      2015/08
# 37                 SAMSUNG Galaxy A40    Nan         Nan      2015/08
# 38                 SAMSUNG Galaxy A11    Nan         Nan      2015/08
# 39                SAMSUNG Galaxy A10s    Nan         Nan      2015/08
# 40                SAMSUNG Galaxy A20s    Nan         Nan      2015/08
